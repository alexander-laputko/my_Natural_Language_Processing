# %%
from fastai.text import *

# %%
import codecs

# Task 1: Choose any text classification dataset
# change file encoding from latin-1 to utf-8
infile = codecs.open('test.csv', 'r', encoding='latin1')
outfile = codecs.open('test-utf8.csv', 'w', encoding='utf-8')

list(map(outfile.write, infile))

infile.close()
outfile.close()

# ok, data in utf-8 format now
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f230e64a6da8> in <module>()
#       3 # Task 1: Choose any text classification dataset
#       4 # change file encoding from latin-1 to utf-8
# ----> 5 infile = codecs.open('test.csv', 'r', encoding='latin1')
#       6 outfile = codecs.open('test-utf8.csv', 'w', encoding='utf-8')
#       7
#
# /usr/lib/python3.6/codecs.py in open(filename, mode, encoding, errors, buffering)
#     895         # Force opening of the file in binary mode
#     896         mode = mode + 'b'
# --> 897     file = builtins.open(filename, mode, buffering)
#     898     if encoding is None:
#     899         return file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
